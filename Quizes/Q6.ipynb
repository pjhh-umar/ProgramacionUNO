# %% [markdown]
# # <center> Quiz 6 </center>
#
# ## Instrucciones:
#
# * #### **Duración**: 1 hora
#
# * #### Resuelve cada ejercicio utilizando  únicamente funciones y estructuras presentadas en clase.
#
# * #### Crear un **Notebook de python** (archivo con extensión `.ipynb`) con las soluciones correspondientes a cada pregunta, señalar  adecuadamente en el notebook la solución de cada pregunta.
#
# * #### Los archivos correspondientes a cada pregunta se deben nombrar de la siguiente manera:
#
# <center> <font size=4><b>TuNombre_TuPrimerApellido_Q6</b></font> </center>
#
#
# * #### Enviar el Notebook de Python al correo **pablo.jorge@aulavirtual.umar.mx** en el asunto escribe: ``**Quiz 6**''. No olvides adjuntar el archivo, de otra forma el examen no será tomado en cuenta.
#
# * ####  Después de las 12:00 horas por cada $5$ minutos de retraso al enviar tu archivo se tendrá  una penalización de $0.75$ puntos menos sobre la calificación final del examen.

# %% [markdown]
# ## Ejercicio 1 (5 puntos)
#
#
# #### En UMARcity, las placas más antiguas de automóviles constan de tres letras mayúsculas seguidas de tres dígitos. Cuando se terminaron todas las matrículas que podian ser creadas con ese patrón, se cambió el formato a cuatro dígitos seguidos de tres letras mayúsculas.
#
# #### Escribe  un programa en Python que solicite al usuario una cadena de caracteres y evalue e imprime  un mensaje que indique si la cadena ingresada corresponde a una placa en formato antiguo o a una placa en formato nuevo. El programa debe mostrar un mensaje apropiado si la cadena ingresada por el usuario no es válida para ningún estilo de matrícula.

# %% [markdown]
# ## Ejercicio 2 (5 puntos)
#
# #### Escribe un programa en Python que solicite al usuario una contraseña (cadena de caracteres) y determine si esta es una **muy buena contraseña** o no. Diremos que una **muy buena contraseña** es aquella que cumple las siguientes características:
#
# ####    1. La contraseña debe tener al menos 8 caracteres.
# ####    2. La contraseña debe a lo más 12 caracteres.
# ####    3. Contenga al menos una letra mayúscula.
# ####    4. Contenga al menos una letra minúscula.
# ####    5. Contenga al menos un número.
# ####    6. La contraseña debe tener al menos un caracter del conjunto {$,@,#}.
#
# #### Imprime mediante un mensaje adecuada si la contraseña ingresada es una muy buena contraseña o no.

# %%
contrasena = 6
